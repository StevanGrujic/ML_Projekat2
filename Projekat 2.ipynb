# %% [markdown]
# <div style="border-radius:10px;
#             background-color:#ffffff;
#             letter-spacing:0.5px; text-align: center;">
#
# <h3 style="padding: 5px 0px; color:#0b0265; font-weight: bold; font-family: Comic Sans MS">
# Library import</h3>
# </div>

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="white")
sns.set(style="whitegrid", color_codes=True)

import warnings

# %% [markdown]
# <div style="border-radius:10px;
#             background-color:#ffffff;
#             letter-spacing:0.5px; text-align: center;">
#
# <h3 style="padding: 5px 0px; color:#0b0265; font-weight: bold; font-family: Comic Sans MS">
# Dataset Features</h3>
# </div>

# %% [markdown]
# **People:**
#
# * `ID`: Customer's unique identifier
# * `Year_Birth`: Customer's birth year
# * `Education`: Customer's education level
# * `Marital_Status`: Customer's marital status
# * `Income`: Customer's yearly household income
# * `Kidhome`: Number of children in customer's household
# * `Teenhome`: Number of teenagers in customer's household
# * `Dt_Customer`: Date of customer's enrollment with the company
# * `Recency`: Number of days since customer's last purchase
# * `Complain`: 1 if the customer complained in the last 2 years, 0 otherwise
#
# **Products:**
#
# * `MntWines`: Amount spent on wine in last 2 years
# * `MntFruits`: Amount spent on fruits in last 2 years
# * `MntMeatProducts`: Amount spent on meat in last 2 years
# * `MntFishProducts`: Amount spent on fish in last 2 years
# * `MntSweetProducts`: Amount spent on sweets in last 2 years
# * `MntGoldProds`: Amount spent on gold in last 2 years
#
# **Promotion:**
#
# * `NumDealsPurchases`: Number of purchases made with a discount
# * `AcceptedCmp1`: 1 if customer accepted the offer in the 1st campaign, 0 otherwise
# * `AcceptedCmp2`: 1 if customer accepted the offer in the 2nd campaign, 0 otherwise
# * `AcceptedCmp3`: 1 if customer accepted the offer in the 3rd campaign, 0 otherwise
# * `AcceptedCmp4`: 1 if customer accepted the offer in the 4th campaign, 0 otherwise
# * `AcceptedCmp5`: 1 if customer accepted the offer in the 5th campaign, 0 otherwise
# * `Response`: 1 if customer accepted the offer in the last campaign, 0 otherwise
#
# **Place:**
#
# * `NumWebPurchases`: Number of purchases made through the company’s website
# * `NumCatalogPurchases`: Number of purchases made using a catalogue
# * `NumStorePurchases`: Number of purchases made directly in stores
# * `NumWebVisitsMonth`: Number of visits to company’s website in the last month

# %% [markdown]
# <div style="border-radius:10px;
#             background-color:#ffffff;
#             letter-spacing:0.5px; text-align: center;">
#
# <h3 style="padding: 5px 0px; color:#0b0265; font-weight: bold; font-family: Comic Sans MS">
# Load and analyse data</h3>
# </div>

# %%
pd.set_option('display.max_columns', None)
df = pd.read_csv("data/marketing_campaign.csv", sep="\t")
df.head(100)
# Out:
#        ID  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0    5524        1957  Graduation         Single  58138.0        0         0
# 1    2174        1954  Graduation         Single  46344.0        1         1
# 2    4141        1965  Graduation       Together  71613.0        0         0
# 3    6182        1984  Graduation       Together  26646.0        1         0
# 4    5324        1981         PhD        Married  58293.0        1         0
# ..    ...         ...         ...            ...      ...      ...       ...
# 95   7516        1983  Graduation        Married  30096.0        1         0
# 96   7247        1960  Graduation          Widow  47916.0        0         1
# 97  11100        1972  Graduation       Divorced  51813.0        1         1
# 98   4646        1951    2n Cycle        Married  78497.0        0         0
# 99   3037        1983         PhD        Married  50150.0        0         0
#
# ...

# %%
df.dtypes
# Out:
# ID                       int64
# Year_Birth               int64
# Education               object
# Marital_Status          object
# Income                 float64
# Kidhome                  int64
# Teenhome                 int64
# Dt_Customer             object
# Recency                  int64
# MntWines                 int64
# MntFruits                int64
# MntMeatProducts          int64
# MntFishProducts          int64
# MntSweetProducts         int64
# MntGoldProds             int64
# NumDealsPurchases        int64
# NumWebPurchases          int64
# NumCatalogPurchases      int64
# NumStorePurchases        int64
# NumWebVisitsMonth        int64
# AcceptedCmp3             int64
# AcceptedCmp4             int64
# AcceptedCmp5             int64
# AcceptedCmp1             int64
# AcceptedCmp2             int64
# Complain                 int64
# Z_CostContact            int64
# Z_Revenue                int64
# Response                 int64
# dtype: object

# %%
df.describe().T
# Out:
#                       count          mean           std     min       25%  \
# ID                   2240.0   5592.159821   3246.662198     0.0   2828.25
# Year_Birth           2240.0   1968.805804     11.984069  1893.0   1959.00
# Income               2216.0  52247.251354  25173.076661  1730.0  35303.00
# Kidhome              2240.0      0.444196      0.538398     0.0      0.00
# Teenhome             2240.0      0.506250      0.544538     0.0      0.00
# Recency              2240.0     49.109375     28.962453     0.0     24.00
# MntWines             2240.0    303.935714    336.597393     0.0     23.75
# MntFruits            2240.0     26.302232     39.773434     0.0      1.00
# MntMeatProducts      2240.0    166.950000    225.715373     0.0     16.00
# MntFishProducts      2240.0     37.525446     54.628979     0.0      3.00
# MntSweetProducts     2240.0     27.062946     41.280498     0.0      1.00
# MntGoldProds         2240.0     44.021875     52.167439     0.0      9.00
# ...

# %%
df.groupby("Education").median()
# Out:
# C:\Users\Petar\AppData\Local\Temp\ipykernel_20524\2361416093.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Education").median()
#                 ID  Year_Birth   Income  Kidhome  Teenhome  Recency  MntWines  \
# Education
# 2n Cycle    5332.0      1975.0  46805.0      0.0       0.0     45.0      48.0
# Basic       5261.5      1979.0  20744.0      1.0       0.0     48.0       2.0
# Graduation  5544.0      1970.0  52028.5      0.0       0.0     50.0     183.0
# Master      5314.5      1968.0  50943.0      0.0       1.0     49.0     179.0
# PhD         5448.0      1967.0  55212.0      0.0       1.0     49.0     276.5
#
#             MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  \
# Education
# ...

# %%
df.groupby("Education").mean()
# Out:
# C:\Users\Petar\AppData\Local\Temp\ipykernel_20524\3485103341.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Education").mean()
#                      ID   Year_Birth        Income   Kidhome  Teenhome  \
# Education
# 2n Cycle    5588.211823  1972.024631  47633.190000  0.477833  0.408867
# Basic       5396.407407  1977.462963  20306.259259  0.629630  0.092593
# Graduation  5652.523514  1969.635315  52720.373656  0.444543  0.494232
# Master      5403.648649  1966.878378  52917.534247  0.454054  0.535135
# PhD         5619.096708  1966.043210  56145.313929  0.401235  0.598765
#
#               Recency    MntWines  MntFruits  MntMeatProducts  \
# Education
# 2n Cycle    48.418719  198.182266  28.955665       141.256158
# ...

# %%
df.groupby("Dt_Customer").median()
# Out:
# C:\Users\Petar\AppData\Local\Temp\ipykernel_20524\862555195.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Dt_Customer").median()
#                  ID  Year_Birth   Income  Kidhome  Teenhome  Recency  \
# Dt_Customer
# 01-01-2013   7711.5      1967.5  34600.0      1.0       1.0     42.5
# 01-01-2014   5237.0      1951.0  54682.0      1.0       1.0     79.0
# 01-02-2013   7124.0      1943.0  48948.0      0.0       0.0     53.0
# 01-02-2014   8749.0      1984.0  37235.0      1.0       0.0     68.0
# 01-03-2013   1524.0      1983.0  54880.0      0.0       0.0     14.0
# ...             ...         ...      ...      ...       ...      ...
# 31-08-2012   6866.0      1977.5  47002.0      0.0       0.0     81.5
# ...

# %%
kategoricki_atributi = ['Education','Marital_Status']
for a in kategoricki_atributi:
    fig, ax = plt.subplots();
    sns.countplot(data=df, y=a, ax=ax);

# %%
df_corr = df.corr()
df_corr = df_corr.apply(lambda x: round(x, 2))
fig, ax = plt.subplots(figsize = (20,20));
sns.heatmap(data=df_corr, annot=True, ax=ax);
# Out:
# C:\Users\Petar\AppData\Local\Temp\ipykernel_20524\439895314.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_corr = df.corr()

# %%
df_reduced = df

# %%
df.isnull().sum()
# Out:
# ID                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Complain                0
# Z_CostContact           0
# Z_Revenue               0
# Response                0
# dtype: int64

# %%
df_reduced = df.dropna()

# %%
df_reduced['Z_CostContact'].value_counts()
# Out:
# 3    2216
# Name: Z_CostContact, dtype: int64

# %%
df_reduced['Z_Revenue'].value_counts()
# Out:
# 11    2216
# Name: Z_Revenue, dtype: int64

# %%
df_reduced = df_reduced.drop(["Z_Revenue", "Z_CostContact"], axis=1)

# %%
df_corr = df_reduced.corr()
df_corr = df_corr.apply(lambda x: round(x, 2))
fig, ax = plt.subplots(figsize = (15,15));
sns.heatmap(data=df_corr, annot=True, ax=ax);
# Out:
# C:\Users\Petar\AppData\Local\Temp\ipykernel_20524\4104659354.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_corr = df_reduced.corr()

# %%
df_reduced['Marital_Status'].unique()
# Out:
# array(['Single', 'Together', 'Married', 'Divorced', 'Widow', 'Alone',
#        'Absurd', 'YOLO'], dtype=object)

# %%
#REPLACING THE CONFLICT VALUES IN Marital_status..
df_reduced['Marital_Status'] = df_reduced['Marital_Status'].replace(['Married', 'Together'],'Relationship')
df_reduced['Marital_Status'] = df_reduced['Marital_Status'].replace(['Divorced', 'Widow', 'Alone', 'YOLO', 'Absurd'],'Single')

# %%
df_reduced['Education'].unique()
# Out:
# array(['Graduation', 'PhD', 'Master', 'Basic', '2n Cycle'], dtype=object)

# %%
#REPLACING THE CONFLICT VALUES IN Marital_status..
df_reduced['Education'] = df_reduced['Education'].replace(['Graduation', 'PhD', 'Master','2n Cycle'],'Academic')
df_reduced['Education'] = df_reduced['Education'].replace(['Basic'],'Non-Academic')

# %%
kategoricki_atributi = ['Education','Marital_Status']
for a in kategoricki_atributi:
    fig, ax = plt.subplots();
    sns.countplot(data=df, y=a, ax=ax);

# %%
# create a new column 'Kids' by summing the 'Kidhome' and 'Teenhome' columns
df_reduced['Kids'] = df_reduced['Kidhome'] + df_reduced['Teenhome']

# get the count of unique values in the 'Kids' column
print("Unique categories present in the Kids:", df_reduced['Kids'].value_counts())

# visualize the 'Kids' column with a bar chart
df_reduced['Kids'].value_counts().plot(kind='bar',color = 'white',edgecolor = "blue",linewidth = 2)

# add a title to the chart
plt.title("Number of kids\n",fontsize=24)

# set the size of the chart
plt.figure(figsize=(8,8))
# Out:
# Unique categories present in the Kids: 1    1117
# 0     633
# 2     416
# 3      50
# Name: Kids, dtype: int64

# %%
df_reduced.drop(['Kidhome', 'Teenhome'],axis=1, inplace=True)

# %%
df.describe()
# Out:
#                  ID   Year_Birth         Income      Kidhome     Teenhome  \
# count   2240.000000  2240.000000    2216.000000  2240.000000  2240.000000
# mean    5592.159821  1968.805804   52247.251354     0.444196     0.506250
# std     3246.662198    11.984069   25173.076661     0.538398     0.544538
# min        0.000000  1893.000000    1730.000000     0.000000     0.000000
# 25%     2828.250000  1959.000000   35303.000000     0.000000     0.000000
# 50%     5458.500000  1970.000000   51381.500000     0.000000     0.000000
# 75%     8427.750000  1977.000000   68522.000000     1.000000     1.000000
# max    11191.000000  1996.000000  666666.000000     2.000000     2.000000
#
#            Recency     MntWines    MntFruits  MntMeatProducts  \
# count  2240.000000  2240.000000  2240.000000      2240.000000
# mean     49.109375   303.935714    26.302232       166.950000
# std      28.962453   336.597393    39.773434       225.715373
# ...

# %%
print(df_reduced["AcceptedCmp1"].value_counts())
# Out:
# 0    2074
# 1     142
# Name: AcceptedCmp1, dtype: int64

# %%
print(df_reduced["AcceptedCmp2"].value_counts())
# Out:
# 0    2186
# 1      30
# Name: AcceptedCmp2, dtype: int64

# %%
print(df_reduced["AcceptedCmp3"].value_counts())
# Out:
# 0    2053
# 1     163
# Name: AcceptedCmp3, dtype: int64

# %%
print(df_reduced["AcceptedCmp4"].value_counts())
# Out:
# 0    2052
# 1     164
# Name: AcceptedCmp4, dtype: int64

# %%
print(df_reduced["AcceptedCmp5"].value_counts())
# Out:
# 0    2054
# 1     162
# Name: AcceptedCmp5, dtype: int64

# %%
df_reduced['TotalAcceptedCmp'] = df_reduced['AcceptedCmp1'] + df_reduced['AcceptedCmp2'] + df_reduced['AcceptedCmp3'] + df_reduced['AcceptedCmp4'] + df_reduced['AcceptedCmp5'] + df_reduced['Response']

# %%
df_reduced.drop(['AcceptedCmp1', 'AcceptedCmp2','AcceptedCmp4', 'AcceptedCmp5','AcceptedCmp3','Response'],axis=1, inplace=True)

# %%
df_reduced['TotalAcceptedCmp'].value_counts()
# Out:
# 0    1611
# 1     369
# 2     139
# 3      51
# 4      36
# 5      10
# Name: TotalAcceptedCmp, dtype: int64

# %%
df_reduced.head(40)
# Out:
#        ID  Year_Birth     Education Marital_Status   Income Dt_Customer  \
# 0    5524        1957      Academic         Single  58138.0  04-09-2012
# 1    2174        1954      Academic         Single  46344.0  08-03-2014
# 2    4141        1965      Academic   Relationship  71613.0  21-08-2013
# 3    6182        1984      Academic   Relationship  26646.0  10-02-2014
# 4    5324        1981      Academic   Relationship  58293.0  19-01-2014
# 5    7446        1967      Academic   Relationship  62513.0  09-09-2013
# 6     965        1971      Academic         Single  55635.0  13-11-2012
# 7    6177        1985      Academic   Relationship  33454.0  08-05-2013
# 8    4855        1974      Academic   Relationship  30351.0  06-06-2013
# 9    5899        1950      Academic   Relationship   5648.0  13-03-2014
# 11    387        1976  Non-Academic   Relationship   7500.0  13-11-2012
# 12   2125        1959      Academic         Single  63033.0  15-11-2013
# ...

# %%
from datetime import datetime

current_year = datetime.now().year
df_reduced['age'] = current_year - df['Year_Birth']

# %%
df_reduced.drop(['ID', 'Year_Birth'],axis=1, inplace=True)

# %%
df_reduced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2216 entries, 0 to 2239
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Education            2216 non-null   object
#  1   Marital_Status       2216 non-null   object
#  2   Income               2216 non-null   float64
#  3   Dt_Customer          2216 non-null   object
#  4   Recency              2216 non-null   int64
#  5   MntWines             2216 non-null   int64
#  6   MntFruits            2216 non-null   int64
#  7   MntMeatProducts      2216 non-null   int64
#  8   MntFishProducts      2216 non-null   int64
#  9   MntSweetProducts     2216 non-null   int64
#  10  MntGoldProds         2216 non-null   int64
#  11  NumDealsPurchases    2216 non-null   int64
#  12  NumWebPurchases      2216 non-null   int64
#  13  NumCatalogPurchases  2216 non-null   int64
#  14  NumStorePurchases    2216 non-null   int64
# ...
